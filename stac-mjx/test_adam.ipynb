# %%
import mujoco
from mujoco import mjx
import jax
from jax import numpy as jnp
from jax.lib import xla_bridge
from dm_control import mjcf
import numpy as np

import os
import pickle
import time
import argparse
import random
import logging 
import sys
import controller as ctrl
import utils

from compute_stac import *
import operations as op
import stac_base

#Turning off warnings bc jax of deprecation warnings
import warnings
warnings.filterwarnings("ignore")

# %cd stac-mjx
# Out:
# [Errno 2] No such file or directory: 'stac-mjx'
# /Users/charleszhang/GitHub/stac-mjx/stac-mjx

# %%
def rootopt_then_frameopt(mj_model, kp_data):
    
    # Create mjx model and data
    mjx_model = mjx.put_model(mj_model)
    mjx_data = mjx.make_data(mjx_model)
    
    # Get and set the offsets of the markers
    offsets = jnp.copy(op.get_site_pos(mjx_model))
    offsets *= utils.params['SCALE_FACTOR']
    
    # print(mjx_model.site_pos, mjx_model.site_pos.shape)
    mjx_model = op.set_site_pos(mjx_model, offsets)

    # forward is used to calculate xpos and such
    mjx_data = mjx.kinematics(mjx_model, mjx_data)
    mjx_data = mjx.com_pos(mjx_model, mjx_data)
    
    # Begin optimization steps
    mjx_data = root_optimization(mjx_model, mjx_data, kp_data)

    print("optimizing first frame")
    return pose_optimization(mjx_model, mjx_data, kp_data)

    # print("starting offset optimization")
    # mjx_model, mjx_data = offset_optimization(mjx_model, mjx_data, kp_data, offsets, q)

# %%
utils.init_params("../params/params.yaml")

# When using nvidia gpu do this thing
if xla_bridge.get_backend().platform == 'gpu':
    os.environ['XLA_FLAGS'] = (
    '--xla_gpu_enable_triton_softmax_fusion=true '
    '--xla_gpu_triton_gemm_any=True '
    '--xla_gpu_enable_async_collectives=true '
    '--xla_gpu_enable_latency_hiding_scheduler=true '
    '--xla_gpu_enable_highest_priority_async_stream=true '
    )
    # Set N_GPUS
    utils.params["N_GPUS"] = jax.local_device_count("gpu")


ratpath = "../models/rodent_stac_optimized.xml"
rat23path = "../models/rat23.mat"
kp_names = utils.loadmat(rat23path)["joint_names"]
utils.params["kp_names"] = kp_names
# argsort returns the indices that would sort the array
stac_keypoint_order = np.argsort(kp_names)   

model = mujoco.MjModel.from_xml_path(ratpath)

model.opt.solver = {
    'cg': mujoco.mjtSolver.mjSOL_CG,
    'newton': mujoco.mjtSolver.mjSOL_NEWTON,
}['cg']

model.opt.iterations = 6
model.opt.ls_iterations = 6

data_path = "../save_data_AVG.mat"

# Load kp_data, /1000 to scale data (from mm to meters)
kp_data = utils.loadmat(data_path)["pred"][:] / 1000

kp_data = ctrl.prep_kp_data(kp_data, stac_keypoint_order)

# Set up mjcf
root = mjcf.from_path(ratpath)
physics, mj_model = ctrl.create_body_sites(root)
ctrl.part_opt_setup(physics)

# %% [markdown]
# ### running q_phase for a couple frames te tune hyperparams to minimize error

# %%
utils.params['Q_LR'] = 1e-3
utils.params['M_LR'] = 1e-4
utils.params['MAXITER'] = 20000
mjx_model, q, x, walker_body_sites, clip_data = ctrl.fit(mj_model, kp_data[:20])
# Out:
# Root Optimization:
# q_opt 1 finished in 0.016587018966674805 with an error of 0.0009948238730430603
# Replace 1 finished in 0.0013530254364013672
# starting q_opt 2
# q_opt 2 finished in 0.004716157913208008 with an error of 0.0009773391066119075
# Replace 2 finished in 0.0005338191986083984
# Root optimization finished in 0.025484800338745117
# Calibration iteration: 1/6
# Pose Optimization:
# Pose Optimization done in 0.17239093780517578
# Frame 1 done in 0.016810894012451172 with a final error of 0.00047071382869035006
# Frame 2 done in 0.009987115859985352 with a final error of 0.0004154726048000157
# Frame 3 done in 0.008481025695800781 with a final error of 0.00037103722570464015
# Frame 4 done in 0.008517265319824219 with a final error of 0.0003326745063532144
# Frame 5 done in 0.008247852325439453 with a final error of 0.00028430274687707424
# Frame 6 done in 0.008331060409545898 with a final error of 0.0002446977305226028
# Frame 7 done in 0.008553028106689453 with a final error of 0.00020171154756098986
# Frame 8 done in 0.008407115936279297 with a final error of 0.00017375110473949462
# Frame 9 done in 0.00740814208984375 with a final error of 0.00012656748003792018
# Frame 10 done in 0.008588075637817383 with a final error of 0.00012180345947854221
# Frame 11 done in 0.007580757141113281 with a final error of 0.0001256891555385664
# Frame 12 done in 0.00873708724975586 with a final error of 0.00011855510820169002
# Frame 13 done in 0.008399009704589844 with a final error of 0.00011759861081372947
# Frame 14 done in 0.0068819522857666016 with a final error of 0.00044001039350405335
# Frame 15 done in 0.008128881454467773 with a final error of 0.00011622245074249804
# Frame 16 done in 0.00867009162902832 with a final error of 0.00011522737622726709
# Frame 17 done in 0.00762176513671875 with a final error of 0.00011860123777296394
# Frame 18 done in 0.0077953338623046875 with a final error of 0.00011894603812834248
# Frame 19 done in 0.006932973861694336 with a final error of 0.00011090556654380634
# Frame 20 done in 0.007746696472167969 with a final error of 8.462191908620298e-05
# starting offset optimization
# Begining offset optimization:
# learned offsets: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  Final error of nan
# offset optimization finished in 0.011336803436279297
# Calibration iteration: 2/6
# Pose Optimization:
# Pose Optimization done in 0.13005495071411133
# Frame 1 done in 0.007294893264770508 with a final error of nan
# Frame 2 done in 0.006310939788818359 with a final error of nan
# Frame 3 done in 0.00693511962890625 with a final error of nan
# Frame 4 done in 0.006781101226806641 with a final error of nan
# Frame 5 done in 0.006571769714355469 with a final error of nan
# Frame 6 done in 0.0063970088958740234 with a final error of nan
# Frame 7 done in 0.006281852722167969 with a final error of nan
# Frame 8 done in 0.006615161895751953 with a final error of nan
# Frame 9 done in 0.006389617919921875 with a final error of nan
# Frame 10 done in 0.006373167037963867 with a final error of nan
# Frame 11 done in 0.006515026092529297 with a final error of nan
# Frame 12 done in 0.006360054016113281 with a final error of nan
# Frame 13 done in 0.006356954574584961 with a final error of nan
# Frame 14 done in 0.006320953369140625 with a final error of nan
# Frame 15 done in 0.006297111511230469 with a final error of nan
# Frame 16 done in 0.006350994110107422 with a final error of nan
# Frame 17 done in 0.006372928619384766 with a final error of nan
# Frame 18 done in 0.006443023681640625 with a final error of nan
# Frame 19 done in 0.006413936614990234 with a final error of nan
# Frame 20 done in 0.0063250064849853516 with a final error of nan
# starting offset optimization
# Begining offset optimization:
# learned offsets: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  Final error of nan
# offset optimization finished in 0.0042171478271484375
# Calibration iteration: 3/6
# Pose Optimization:
# Pose Optimization done in 0.159959077835083
# Frame 1 done in 0.006440877914428711 with a final error of nan
# Frame 2 done in 0.0063211917877197266 with a final error of nan
# Frame 3 done in 0.006679058074951172 with a final error of nan
# Frame 4 done in 0.006345987319946289 with a final error of nan
# Frame 5 done in 0.006489992141723633 with a final error of nan
# Frame 6 done in 0.006289958953857422 with a final error of nan
# Frame 7 done in 0.006345033645629883 with a final error of nan
# Frame 8 done in 0.013176918029785156 with a final error of nan
# Frame 9 done in 0.020057201385498047 with a final error of nan
# Frame 10 done in 0.008797883987426758 with a final error of nan
# Frame 11 done in 0.013936996459960938 with a final error of nan
# Frame 12 done in 0.008347272872924805 with a final error of nan
# Frame 13 done in 0.007112979888916016 with a final error of nan
# Frame 14 done in 0.006197929382324219 with a final error of nan
# Frame 15 done in 0.006237983703613281 with a final error of nan
# Frame 16 done in 0.00633692741394043 with a final error of nan
# Frame 17 done in 0.005900859832763672 with a final error of nan
# Frame 18 done in 0.006367921829223633 with a final error of nan
# Frame 19 done in 0.006132364273071289 with a final error of nan
# Frame 20 done in 0.006102800369262695 with a final error of nan
# starting offset optimization
# Begining offset optimization:
# learned offsets: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  Final error of nan
# offset optimization finished in 0.0046231746673583984
# Calibration iteration: 4/6
# Pose Optimization:
# Pose Optimization done in 0.12337183952331543
# Frame 1 done in 0.0064849853515625 with a final error of nan
# Frame 2 done in 0.006234169006347656 with a final error of nan
# Frame 3 done in 0.006132364273071289 with a final error of nan
# Frame 4 done in 0.0061168670654296875 with a final error of nan
# Frame 5 done in 0.006320953369140625 with a final error of nan
# Frame 6 done in 0.005961179733276367 with a final error of nan
# Frame 7 done in 0.006010770797729492 with a final error of nan
# Frame 8 done in 0.00605010986328125 with a final error of nan
# Frame 9 done in 0.0059661865234375 with a final error of nan
# Frame 10 done in 0.005994558334350586 with a final error of nan
# Frame 11 done in 0.006045341491699219 with a final error of nan
# Frame 12 done in 0.005966663360595703 with a final error of nan
# Frame 13 done in 0.00628209114074707 with a final error of nan
# Frame 14 done in 0.00617527961730957 with a final error of nan
# Frame 15 done in 0.0060307979583740234 with a final error of nan
# Frame 16 done in 0.006240129470825195 with a final error of nan
# Frame 17 done in 0.006299018859863281 with a final error of nan
# Frame 18 done in 0.006296873092651367 with a final error of nan
# Frame 19 done in 0.0061969757080078125 with a final error of nan
# Frame 20 done in 0.006232023239135742 with a final error of nan
# starting offset optimization
# Begining offset optimization:
# learned offsets: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  Final error of nan
# offset optimization finished in 0.004153013229370117
# Calibration iteration: 5/6
# Pose Optimization:
# Pose Optimization done in 0.12322020530700684
# Frame 1 done in 0.006354808807373047 with a final error of nan
# Frame 2 done in 0.006148099899291992 with a final error of nan
# Frame 3 done in 0.006142139434814453 with a final error of nan
# Frame 4 done in 0.006027936935424805 with a final error of nan
# Frame 5 done in 0.005994081497192383 with a final error of nan
# Frame 6 done in 0.006061077117919922 with a final error of nan
# Frame 7 done in 0.005986690521240234 with a final error of nan
# Frame 8 done in 0.005953073501586914 with a final error of nan
# Frame 9 done in 0.006020069122314453 with a final error of nan
# Frame 10 done in 0.006009101867675781 with a final error of nan
# Frame 11 done in 0.006070137023925781 with a final error of nan
# Frame 12 done in 0.0060269832611083984 with a final error of nan
# Frame 13 done in 0.006273746490478516 with a final error of nan
# Frame 14 done in 0.006898164749145508 with a final error of nan
# Frame 15 done in 0.0060160160064697266 with a final error of nan
# Frame 16 done in 0.0063588619232177734 with a final error of nan
# Frame 17 done in 0.006140232086181641 with a final error of nan
# Frame 18 done in 0.006162881851196289 with a final error of nan
# Frame 19 done in 0.006118059158325195 with a final error of nan
# Frame 20 done in 0.006132841110229492 with a final error of nan
# starting offset optimization
# Begining offset optimization:
# learned offsets: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  Final error of nan
# offset optimization finished in 0.004080057144165039
# Calibration iteration: 6/6
# Pose Optimization:
# Pose Optimization done in 0.12758827209472656
# Frame 1 done in 0.006520748138427734 with a final error of nan
# Frame 2 done in 0.006294965744018555 with a final error of nan
# Frame 3 done in 0.006285190582275391 with a final error of nan
# Frame 4 done in 0.0062749385833740234 with a final error of nan
# Frame 5 done in 0.006276845932006836 with a final error of nan
# Frame 6 done in 0.006378173828125 with a final error of nan
# Frame 7 done in 0.0062940120697021484 with a final error of nan
# Frame 8 done in 0.006325960159301758 with a final error of nan
# Frame 9 done in 0.006504058837890625 with a final error of nan
# Frame 10 done in 0.006392955780029297 with a final error of nan
# Frame 11 done in 0.00640416145324707 with a final error of nan
# Frame 12 done in 0.006331920623779297 with a final error of nan
# Frame 13 done in 0.006265163421630859 with a final error of nan
# Frame 14 done in 0.006309986114501953 with a final error of nan
# Frame 15 done in 0.006310701370239258 with a final error of nan
# Frame 16 done in 0.006306171417236328 with a final error of nan
# Frame 17 done in 0.006446123123168945 with a final error of nan
# Frame 18 done in 0.0062410831451416016 with a final error of nan
# Frame 19 done in 0.00630497932434082 with a final error of nan
# Frame 20 done in 0.0068209171295166016 with a final error of nan
# starting offset optimization
# Begining offset optimization:
# learned offsets: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  Final error of nan
# offset optimization finished in 0.00402522087097168
# Final pose optimization
# Pose Optimization:
# Pose Optimization done in 0.12855792045593262
# Frame 1 done in 0.006615161895751953 with a final error of nan
# Frame 2 done in 0.006426811218261719 with a final error of nan
# Frame 3 done in 0.006504058837890625 with a final error of nan
# Frame 4 done in 0.006303071975708008 with a final error of nan
# Frame 5 done in 0.006363868713378906 with a final error of nan
# Frame 6 done in 0.006528139114379883 with a final error of nan
# Frame 7 done in 0.0063741207122802734 with a final error of nan
# Frame 8 done in 0.006384849548339844 with a final error of nan
# Frame 9 done in 0.0064389705657958984 with a final error of nan
# Frame 10 done in 0.006800174713134766 with a final error of nan
# Frame 11 done in 0.00633692741394043 with a final error of nan
# Frame 12 done in 0.006528139114379883 with a final error of nan
# Frame 13 done in 0.0064237117767333984 with a final error of nan
# Frame 14 done in 0.006314992904663086 with a final error of nan
# Frame 15 done in 0.006292104721069336 with a final error of nan
# Frame 16 done in 0.006382942199707031 with a final error of nan
# Frame 17 done in 0.0062830448150634766 with a final error of nan
# Frame 18 done in 0.006298065185546875 with a final error of nan
# Frame 19 done in 0.006356000900268555 with a final error of nan
# Frame 20 done in 0.006284952163696289 with a final error of nan
