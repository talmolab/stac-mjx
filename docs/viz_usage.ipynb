# %% [markdown]
# ### Render stac outputs with mujoco

# %%
# glfw is faster, but use osmesa if glfw not available
# %env MUJOCO_GL=glfw
# %env PYOPENGL_PLATFORM=glfw

import os
import mediapy as media

from stac_mjx.viz import mujoco_viz
from stac_mjx import main
from stac_mjx import utils

# Disable jax's memory preallocation if you're running multiple notebooks using jax
# os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = "false" 

stac_config_path = "../configs/stac.yaml"
model_config_path = "../configs/rodent.yaml"

cfg = main.load_configs(stac_config_path, model_config_path)
# Out:
# env: MUJOCO_GL=glfw
# env: PYOPENGL_PLATFORM=glfw

# %%
# set args and initialize params
rat_xml = "./models/rodent.xml"
data_path = "./transform.p"
n_frames=250
save_path="./videos/direct_render.mp4"

# Call mujoco_viz
frames = mujoco_viz(data_path, rat_xml, n_frames, save_path, start_frame=84*250)

# Show the video in the notebook (it is also saved to the save_path)
media.show_video(frames, fps=utils.params["RENDER_FPS"])
# Out:
# /Users/charleszhang/miniforge3/envs/stac-mjx/lib/python3.11/site-packages/imageio_ffmpeg/_utils.py:7: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_filename
# rendering frame 0
# /Users/charleszhang/miniforge3/envs/stac-mjx/lib/python3.11/subprocess.py:1885: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _fork_exec(
# rendering frame 100
# rendering frame 200
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="1920" height="1200" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
